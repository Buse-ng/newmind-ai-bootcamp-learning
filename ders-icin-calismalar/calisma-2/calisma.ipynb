# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: langchain in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 2)) (0.3.25)
# Requirement already satisfied: langchain-core in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 3)) (0.3.61)
# Requirement already satisfied: langchain-community in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 4)) (0.3.24)
# Requirement already satisfied: langchain-openai in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 5)) (0.3.18)
# Requirement already satisfied: langchain-neo4j in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 6)) (0.4.0)
# Requirement already satisfied: openai in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 9)) (1.81.0)
# Requirement already satisfied: tiktoken in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 10)) (0.9.0)
# Requirement already satisfied: neo4j in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 13)) (5.28.1)
# Requirement already satisfied: python-dotenv in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from -r requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain->-r requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core->-r requirements.txt (line 3)) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core->-r requirements.txt (line 3)) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core->-r requirements.txt (line 3)) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonpatch<2.0,>=1.33->langchain-core->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (0.23.0)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=2.7.4->langchain->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (3.2.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-community->-r requirements.txt (line 4)) (3.11.18)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-community->-r requirements.txt (line 4)) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-community->-r requirements.txt (line 4)) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-community->-r requirements.txt (line 4)) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-community->-r requirements.txt (line 4)) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (22.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community->-r requirements.txt (line 4)) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (1.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai->-r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai->-r requirements.txt (line 9)) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai->-r requirements.txt (line 9)) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from openai->-r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tiktoken->-r requirements.txt (line 10)) (2022.10.31)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: neo4j-graphrag<2.0.0,>=1.5.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-neo4j->-r requirements.txt (line 6)) (1.7.0)
# Requirement already satisfied: pytz in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j->-r requirements.txt (line 13)) (2022.6)
# Requirement already satisfied: fsspec<2025.0.0,>=2024.9.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j->-r requirements.txt (line 6)) (2024.12.0)
# Requirement already satisfied: json-repair<0.40.0,>=0.39.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j->-r requirements.txt (line 6)) (0.39.1)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j->-r requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j->-r requirements.txt (line 6)) (6.0.12.20250516)
# Requirement already satisfied: colorama in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from tqdm>4->openai->-r requirements.txt (line 9)) (0.4.6)

# %% [markdown]
# ## 2. Ortam Değişkenleri ve Bağlantı Kurulumu

# %%
import os
from dotenv import load_dotenv
from neo4j import GraphDatabase
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_community.graphs import Neo4jGraph
from langchain_community.chains.graph_qa.cypher import GraphCypherQAChain

from langchain_core.prompts import ChatPromptTemplate
from langchain.schema import StrOutputParser

load_dotenv()
# Out:
# True

# %%
# Neo4j Bağlantı Bilgilerim
uri = os.getenv("NEO4J_URI")
user = os.getenv("NEO4J_USERNAME")
password = os.getenv("NEO4J_PASSWORD")

# %%
# !pip install -U langchain-neo4j
# Out:
# Requirement already satisfied: langchain-neo4j in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-neo4j) (0.3.25)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-neo4j) (0.3.61)
# Requirement already satisfied: neo4j<6.0.0,>=5.25.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-neo4j) (5.28.1)
# Requirement already satisfied: neo4j-graphrag<2.0.0,>=1.5.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-neo4j) (1.7.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.3.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.11.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain<0.4.0,>=0.3.7->langchain-neo4j) (4.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.8->langchain-neo4j) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.23.0)
# Requirement already satisfied: anyio in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (4.9.0)
# Requirement already satisfied: certifi in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2022.9.24)
# Requirement already satisfied: httpcore==1.* in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.0.9)
# Requirement already satisfied: idna in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (3.4)
# Requirement already satisfied: h11>=0.16 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.16.0)
# Requirement already satisfied: pytz in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j<6.0.0,>=5.25.0->langchain-neo4j) (2022.6)
# Requirement already satisfied: fsspec<2025.0.0,>=2024.9.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (2024.12.0)
# Requirement already satisfied: json-repair<0.40.0,>=0.39.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (0.39.1)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (5.5.0)
# Requirement already satisfied: types-pyyaml<7.0.0.0,>=6.0.12.20240917 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from neo4j-graphrag<2.0.0,>=1.5.0->langchain-neo4j) (6.0.12.20250516)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.1.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests<3,>=2->langchain<0.4.0,>=0.3.7->langchain-neo4j) (2.4.0)
# Requirement already satisfied: greenlet>=1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4.0,>=0.3.7->langchain-neo4j) (3.2.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.7->langchain-neo4j) (1.3.1)

# %%
from langchain_neo4j import Neo4jGraph

# %%
# Neo4j Graph objesi oluşturma
graph = Neo4jGraph(
    url=uri,
    username=user,
    password=password
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\langchain_neo4j\graphs\neo4j_graph.py:172, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     171 try:
# --> 172     self.refresh_schema()
#     173 except neo4j.exceptions.ClientError as e:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\langchain_neo4j\graphs\neo4j_graph.py:278, in Neo4jGraph.refresh_schema(self)
#     277 self._check_driver_state()
# --> 278 self.structured_schema = get_structured_schema(
#     279     driver=self._driver,
#     280     is_enhanced=self._enhanced_schema,
#     281     database=self._database,
#     282     timeout=self.timeout,
#     283     sanitize=self.sanitize,
#     284 )
#     285 self.schema = format_schema(
#     286     schema=self.structured_schema, is_enhanced=self._enhanced_schema
#     287 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j_graphrag\schema.py:289, in get_structured_schema(driver, is_enhanced, database, timeout, sanitize)
#     235 """
#     236 Returns the structured schema of the graph.
#     237
#    (...)
#     285     dict[str, Any]: the graph schema information in a structured format.
#     286 """
#     287 node_properties = [
#     288     data["output"]
# --> 289     for data in query_database(
#     290         driver=driver,
#     291         query=NODE_PROPERTIES_QUERY,
#     292         params={
#     293             "EXCLUDED_LABELS": EXCLUDED_LABELS
#     294             + [BASE_ENTITY_LABEL, BASE_KG_BUILDER_LABEL]
#     295         },
#     296         database=database,
#     297         timeout=timeout,
#     298         sanitize=sanitize,
#     299     )
#     300 ]
#     302 rel_properties = [
#     303     data["output"]
#     304     for data in query_database(
#    (...)
#     311     )
#     312 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j_graphrag\schema.py:164, in query_database(driver, query, params, session_params, database, timeout, sanitize)
#     163 if not session_params:
# --> 164     data = driver.execute_query(
#     165         Query(text=query, timeout=timeout),
#     166         database_=database,
#     167         parameters_=params,
#     168     )
#     169     json_data = [r.data() for r in data.records]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\driver.py:970, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     969 with session._pipelined_begin:
# --> 970     return session._run_transaction(
#     971         access_mode,
#     972         TelemetryAPI.DRIVER,
#     973         work,
#     974         (query_str, parameters, result_transformer_),
#     975         {},
#     976     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\work\session.py:583, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     582 try:
# --> 583     result = transaction_function(tx, *args, **kwargs)
#     584 except asyncio.CancelledError:
#     585     # if cancellation callback has not been called yet:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_work\query.py:144, in unit_of_work.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     143 def wrapped(*args, **kwargs):
# --> 144     return f(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\driver.py:1306, in _work(tx, query, parameters, transformer)
#    1300 def _work(
#    1301     tx: ManagedTransaction,
#    1302     query: te.LiteralString,
#    1303     parameters: dict[str, t.Any],
#    1304     transformer: t.Callable[[Result], t.Union[_T]],
#    1305 ) -> _T:
# -> 1306     res = tx.run(query, parameters)
#    1307     return transformer(res)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\work\transaction.py:206, in TransactionBase.run(self, query, parameters, **kwparameters)
#     205 parameters = dict(parameters or {}, **kwparameters)
# --> 206 result._tx_ready_run(query, parameters)
#     208 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\work\result.py:177, in Result._tx_ready_run(self, query, parameters)
#     173 def _tx_ready_run(self, query, parameters):
#     174     # BEGIN+RUN does not carry any extra on the RUN message.
#     175     # BEGIN {extra}
#     176     # RUN "query" {parameters} {extra}
# --> 177     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\work\result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\work\result.py:430, in Result._attach(self)
#     429 while self._attached is False:
# --> 430     self._connection.fetch_message()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     183 try:
# --> 184     func(*args, **kwargs)
#     185 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\io\_bolt5.py:500, in Bolt5x0._process_message(self, tag, fields)
#     499 try:
# --> 500     response.on_failure(summary_metadata or {})
#     501 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureNotFound} {message: There is no procedure with the name `apoc.meta.data` registered for this database instance. Please ensure you've spelled the procedure name correctly and that the procedure is properly deployed.}
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [11], line 2
#       1 # Neo4j Graph objesi oluşturma
# ----> 2 graph = Neo4jGraph(
#       3     url=uri,
#       4     username=user,
#       5     password=password
#       6 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\langchain_neo4j\graphs\neo4j_graph.py:175, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     173 except neo4j.exceptions.ClientError as e:
#     174     if e.code == "Neo.ClientError.Procedure.ProcedureNotFound":
# --> 175         raise ValueError(
#     176             "Could not use APOC procedures. "
#     177             "Please ensure the APOC plugin is installed in Neo4j and that "
#     178             "'apoc.meta.data()' is allowed in Neo4j configuration "
#     179         )
#     180     raise e
#
# ValueError: Could not use APOC procedures. Please ensure the APOC plugin is installed in Neo4j and that 'apoc.meta.data()' is allowed in Neo4j configuration

# %%
# OpenAI API Anahtarı
openai_api_key = os.getenv("OPENAI_API_KEY")

# %%
import langchain
langchain.verbose = False
langchain.debug = False
langchain.llm_cache = False

# hata verdiği icin

# %%
# LLM ve Embedding Modeli

llm = ChatOpenAI(
    openai_api_key=os.getenv("OPENAI_API_KEY"),
    model="gpt-4.1-nano-2025-04-14"
)
embeddings = OpenAIEmbeddings(openai_api_key=openai_api_key)

# %% [markdown]
# ## 3. Graph Veritabanı Şemasını LLM'e Tanıtma
#
# LLM'in graph veritabanınız hakkında bilgi sahibi olması, doğru Cypher sorguları üretebilmesi için önemlidir. Langchain, bu şemayı otomatik olarak çekebilir veya siz manuel olarak sağlayabilirsiniz.

# %%
# # Graph şemasını al (Otomatik)
# schema = graph.get_schema
# print("Graph Şeması:\n", schema)

# İsterseniz şemayı daha detaylı ve doğal dilde tanımlayabilirsiniz.
# Bu, özellikle karmaşık şemalarda LLM'in performansını artırabilir.
# Örneğin:
schema_description = """
Node türleri:
- Recipe: Yemek tariflerini temsil eder. Özellikleri: name, difficulty, time_minutes.
- Ingredient: Malzemeleri temsil eder. Özellikleri: name, category.
- Flavor: Tatları temsil eder. Özellikleri: name.
- Technique: Pişirme tekniklerini temsil eder. Özellikleri: name.
İlişki türleri:
- CONTAINS: Bir tarifin bir malzemeyi içerdiğini gösterir (Recipe -> Ingredient).
- HAS_FLAVOR: Bir tarifin belirli bir tada sahip olduğunu gösterir (Recipe -> Flavor).
- USES_TECHNIQUE: Bir tarifin belirli bir tekniği kullandığını gösterir (Recipe -> Technique).
- CAN_REPLACE: Bir malzemenin başka bir malzemenin yerine kullanılabileceğini gösterir (Ingredient -> Ingredient).
"""
schema_description
# Out:
# '\nNode türleri:\n- Recipe: Yemek tariflerini temsil eder. Özellikleri: name, difficulty, time_minutes.\n- Ingredient: Malzemeleri temsil eder. Özellikleri: name, category.\n- Flavor: Tatları temsil eder. Özellikleri: name.\n- Technique: Pişirme tekniklerini temsil eder. Özellikleri: name.\nİlişki türleri:\n- CONTAINS: Bir tarifin bir malzemeyi içerdiğini gösterir (Recipe -> Ingredient).\n- HAS_FLAVOR: Bir tarifin belirli bir tada sahip olduğunu gösterir (Recipe -> Flavor).\n- USES_TECHNIQUE: Bir tarifin belirli bir tekniği kullandığını gösterir (Recipe -> Technique).\n- CAN_REPLACE: Bir malzemenin başka bir malzemenin yerine kullanılabileceğini gösterir (Ingredient -> Ingredient).\n'

# %%
# 2. Detaylı Manuel Şema Tanımlaması
# LLM'in sorguları daha iyi anlaması ve daha doğru Cypher üretmesi için
# şemayı doğal dilde, daha açıklayıcı bir şekilde tanımlayabilirsiniz.
# Bu, özellikle node'ların ve ilişkilerin anlamsal rollerini vurgulamak
# veya belirli özelliklerin ne anlama geldiğini açıklamak için önemlidir.

# Sizin sağladığınız Cypher komutlarına ve CSV yapılarına göre detaylı bir şema:
detailed_schema_description = """
Graph veritabanı yemek tarifleri, malzemeler, tatlar ve pişirme teknikleri hakkında bilgi içerir.

**Node Etiketleri (Düğüm Türleri):**

1.  **Recipe (Tarif):**
    *   `id`: Tarif için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
    *   `name`: Tarifin adı (String). Örnek: "Sütlaç", "Kek".
    *   `difficulty`: Tarifin zorluk derecesi (String). Olası değerler: "Kolay", "Orta", "Zor".
    *   `time_minutes`: Tarifin hazırlanma süresi (dakika cinsinden Float). Örnek: 45.0, 60.0.
    *   *Ek Etiketler (Koşullu):*
        *   `SweetDish`: Tarif "Tatlı" lezzetine sahipse bu etiket eklenir.
        *   `CreamyDish`: Tarif "Kremamsı" lezzetine sahipse bu etiket eklenir.

2.  **Ingredient (Malzeme):**
    *   `id`: Malzeme için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
    *   `name`: Malzemenin adı (String). Örnek: "Şeker", "Süt", "Un".
    *   `category`: Malzemenin kategorisi (String). Örnek: "Süt Ürünü", "Tahıl", "Tatlandırıcı".
    *   *Ek Etiketler (Koşullu):*
        *   `Substitute`: Bu malzeme başka bir malzemenin yerine kullanılabiliyorsa bu etiket eklenir.

3.  **Flavor (Lezzet/Tat):**
    *   `id`: Lezzet için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
    *   `name`: Lezzetin adı (String). Örnek: "Tatlı", "Kremamsı", "Karamelli".

4.  **Technique (Pişirme Tekniği):**
    *   `id`: Teknik için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
    *   `name`: Pişirme tekniğinin adı (String). Örnek: "Fırınlama", "Kaynatma", "Karıştırma", "Soğutma".

**İlişki Türleri:**

1.  **CONTAINS (İçerir):** Bir tarifin hangi malzemeleri içerdiğini gösterir.
    *   Başlangıç Düğümü: `Recipe`
    *   Bitiş Düğümü: `Ingredient`
    *   Yön: `(Recipe)-[:CONTAINS]->(Ingredient)`
    *   Örnek: (Sütlaç)-[:CONTAINS]->(Şeker)

2.  **HAS_FLAVOR (Lezzete Sahip):** Bir tarifin hangi lezzet profiline sahip olduğunu gösterir.
    *   Başlangıç Düğümü: `Recipe`
    *   Bitiş Düğümü: `Flavor`
    *   Yön: `(Recipe)-[:HAS_FLAVOR]->(Flavor)`
    *   Örnek: (Sütlaç)-[:HAS_FLAVOR]->(Tatlı)

3.  **USES_TECHNIQUE (Teknik Kullanır):** Bir tarifin hazırlanmasında hangi pişirme tekniklerinin kullanıldığını gösterir.
    *   Başlangıç Düğümü: `Recipe`
    *   Bitiş Düğümü: `Technique`
    *   Yön: `(Recipe)-[:USES_TECHNIQUE]->(Technique)`
    *   Örnek: (Kek)-[:USES_TECHNIQUE]->(Fırınlama)

4.  **CAN_REPLACE (Yerine Kullanılabilir):** Bir malzemenin başka bir malzemenin yerine alternatif olarak kullanılabileceğini gösterir.
    *   Başlangıç Düğümü: `Ingredient`
    *   Bitiş Düğümü: `Ingredient`
    *   Yön: `(Ingredient)-[:CAN_REPLACE]->(Ingredient)`
    *   Örnek: (Bal)-[:CAN_REPLACE]->(Şeker)

**Önemli Notlar:**
*   Tüm `id` alanları, ilgili düğüm tipi için benzersizliği garanti eden kısıtlamalara (constraints) sahiptir.
*   `Recipe` düğümlerindeki `time_minutes` özelliği sayısal (float) bir değerdir.
"""

print("--- Detaylı Manuel Tanımlanmış Graph Şeması ---")
print(detailed_schema_description)
print("-----------------------------------------------\n")

# Bu detaylı şemayı LLM zincirlerinize (örneğin GraphCypherQAChain) iletebilirsiniz.
# Genellikle zincir oluşturulurken `graph_schema` veya benzer bir parametre ile bu bilgi verilir
# ya da prompt'un bir parçası olarak LLM'e sunulur.

# Örnek: GraphCypherQAChain'e detaylı şemayı verme (kullanım senaryosuna göre uyarlanabilir)
# from langchain.chains import GraphCypherQAChain
#
# cypher_qa_chain_detailed_schema = GraphCypherQAChain.from_llm(
#     llm=llm,
#     graph=graph, # Neo4jGraph objesi
#     verbose=True,
#     graph_schema=detailed_schema_description # Detaylı şemayı burada belirtiyoruz
#     # Bazı Langchain versiyonlarında/yapılarında bu doğrudan parametre olmayabilir,
#     # o zaman prompt template'ine eklenmesi gerekebilir.
# )
#
# soru_detayli_sema_ile = "Tatlı lezzetine sahip ve fırınlama tekniği kullanılan tarifler hangileridir?"
# yanıt_detayli_sema_ile = cypher_qa_chain_detailed_schema.invoke({"query": soru_detayli_sema_ile})
# print(f"Soru (Detaylı Şema ile): {soru_detayli_sema_ile}\nYanıt: {yanıt_detayli_sema_ile['result']}\n")
# Out:
# --- Detaylı Manuel Tanımlanmış Graph Şeması ---
#
# Graph veritabanı yemek tarifleri, malzemeler, tatlar ve pişirme teknikleri hakkında bilgi içerir.
#
# **Node Etiketleri (Düğüm Türleri):**
#
# 1.  **Recipe (Tarif):**
#     *   `id`: Tarif için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
#     *   `name`: Tarifin adı (String). Örnek: "Sütlaç", "Kek".
#     *   `difficulty`: Tarifin zorluk derecesi (String). Olası değerler: "Kolay", "Orta", "Zor".
#     *   `time_minutes`: Tarifin hazırlanma süresi (dakika cinsinden Float). Örnek: 45.0, 60.0.
#     *   *Ek Etiketler (Koşullu):*
#         *   `SweetDish`: Tarif "Tatlı" lezzetine sahipse bu etiket eklenir.
#         *   `CreamyDish`: Tarif "Kremamsı" lezzetine sahipse bu etiket eklenir.
#
# 2.  **Ingredient (Malzeme):**
#     *   `id`: Malzeme için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
#     *   `name`: Malzemenin adı (String). Örnek: "Şeker", "Süt", "Un".
#     *   `category`: Malzemenin kategorisi (String). Örnek: "Süt Ürünü", "Tahıl", "Tatlandırıcı".
#     *   *Ek Etiketler (Koşullu):*
#         *   `Substitute`: Bu malzeme başka bir malzemenin yerine kullanılabiliyorsa bu etiket eklenir.
#
# 3.  **Flavor (Lezzet/Tat):**
#     *   `id`: Lezzet için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
#     *   `name`: Lezzetin adı (String). Örnek: "Tatlı", "Kremamsı", "Karamelli".
#
# 4.  **Technique (Pişirme Tekniği):**
#     *   `id`: Teknik için benzersiz bir tanımlayıcı (String, Zorunlu, UNIQUE).
#     *   `name`: Pişirme tekniğinin adı (String). Örnek: "Fırınlama", "Kaynatma", "Karıştırma", "Soğutma".
#
# **İlişki Türleri:**
#
# 1.  **CONTAINS (İçerir):** Bir tarifin hangi malzemeleri içerdiğini gösterir.
#     *   Başlangıç Düğümü: `Recipe`
#     *   Bitiş Düğümü: `Ingredient`
#     *   Yön: `(Recipe)-[:CONTAINS]->(Ingredient)`
#     *   Örnek: (Sütlaç)-[:CONTAINS]->(Şeker)
#
# 2.  **HAS_FLAVOR (Lezzete Sahip):** Bir tarifin hangi lezzet profiline sahip olduğunu gösterir.
#     *   Başlangıç Düğümü: `Recipe`
#     *   Bitiş Düğümü: `Flavor`
#     *   Yön: `(Recipe)-[:HAS_FLAVOR]->(Flavor)`
#     *   Örnek: (Sütlaç)-[:HAS_FLAVOR]->(Tatlı)
#
# 3.  **USES_TECHNIQUE (Teknik Kullanır):** Bir tarifin hazırlanmasında hangi pişirme tekniklerinin kullanıldığını gösterir.
#     *   Başlangıç Düğümü: `Recipe`
#     *   Bitiş Düğümü: `Technique`
#     *   Yön: `(Recipe)-[:USES_TECHNIQUE]->(Technique)`
#     *   Örnek: (Kek)-[:USES_TECHNIQUE]->(Fırınlama)
#
# 4.  **CAN_REPLACE (Yerine Kullanılabilir):** Bir malzemenin başka bir malzemenin yerine alternatif olarak kullanılabileceğini gösterir.
#     *   Başlangıç Düğümü: `Ingredient`
#     *   Bitiş Düğümü: `Ingredient`
#     *   Yön: `(Ingredient)-[:CAN_REPLACE]->(Ingredient)`
#     *   Örnek: (Bal)-[:CAN_REPLACE]->(Şeker)
#
# **Önemli Notlar:**
# *   Tüm `id` alanları, ilgili düğüm tipi için benzersizliği garanti eden kısıtlamalara (constraints) sahiptir.
# *   `Recipe` düğümlerindeki `time_minutes` özelliği sayısal (float) bir değerdir.
#
# -----------------------------------------------

# %% [markdown]
# ## 4. Doğal Dil ile Graph Sorgulama (LLM Destekli Cypher Üretimi)
#
# Langchain'in GraphCypherQAChain'i, doğal dilde sorulan soruları Cypher sorgularına çevirip veritabanında çalıştırarak yanıtlar üretir.

# %%
# Soru-Cevap Zinciri Oluşturma
cypher_qa_chain = GraphCypherQAChain.from_llm(
    llm=llm,
    graph=graph,
    verbose=True
)

# Doğal dilde sorgular yapma
soru1 = "Sütlaç hangi malzemeleri içerir?"
yanit1 = cypher_qa_chain.invoke({"query": soru1})
print(f"Soru: {soru1}\nYanıt: {yanit1['result']}\n")

soru2 = "Fırınlama tekniği kullanan ve zorluk derecesi 'Zor' olan tarifler hangileridir?"
yanit2 = cypher_qa_chain.invoke({"query": soru2})
print(f"Soru: {soru2}\nYanıt: {yanit2['result']}\n")

soru3 = "Kremamsı tada sahip tarifler nelerdir?"
yanit3 = cypher_qa_chain.invoke({"query": soru3})
print(f"Soru: {soru3}\nYanıt: {yanit3['result']}\n")

soru4 = "Şeker yerine kullanılabilecek malzemeler nelerdir?"
yanit4 = cypher_qa_chain.invoke({"query": soru4})
print(f"Soru: {soru4}\nYanıt: {yanit4['result']}\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 from langchain.chains import GraphCypherQAChain
#       3 # Soru-Cevap Zinciri Oluşturma
#       4 cypher_qa_chain = GraphCypherQAChain.from_llm(
#       5     llm=llm,
#       6     graph=graph,
#       7     verbose=True
#       8 )
#
# ModuleNotFoundError: No module named 'langchain.chains'; 'langchain' is not a package

# %% [markdown]
# ## 5. Kendi Zincirlerinizi (Chains) Oluşturma
# Daha spesifik görevler için kendi özel zincirlerinizi oluşturabilirsiniz. Örneğin, eldeki malzemelere göre tarif öneren bir zincir:

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnablePassthrough

# Malzemelere göre tarif öneren zincir
prompt_template = PromptTemplate(
    input_variables=["malzemeler", "schema"],
    template="""
    Sen bir yemek tarifi uzmanısın ve bir graph veritabanına erişimin var.
    Graph Şeması:
    {schema}

    Kullanıcının elinde şu malzemeler var: {malzemeler}.
    Bu malzemelerin çoğunu veya tamamını içeren, veritabanındaki tariflerden 2 tane öner.
    Sadece tarif isimlerini ve neden önerdiğini kısaca belirt.
    Eğer uygun tarif bulamazsan, bulamadığını belirt.
    Cypher sorgusunu şu formatta üret:
    ```
    MATCH (r:Recipe)-[:CONTAINS]->(i:Ingredient)
    WHERE i.name IN $malzeme_listesi
    // Diğer koşullar ve return ifadesi
    ```
    """
)

def malzemeler_ile_tarif_bul_ve_oner(user_input: dict):
    malzemeler_listesi = [m.strip() for m in user_input["malzemeler"].split(',')]

    # LLM'den Cypher sorgusu üretmesini isteyelim (basit bir örnek, daha karmaşık hale getirilebilir)
    # Gerçek bir uygulamada, bu kısım daha sofistike bir LLM çağrısı veya GraphCypherQAChain benzeri bir yapı olabilir.
    # Şimdilik, örnek bir sorgu kullanalım.
    # Gerçekçi bir senaryoda, LLM'e malzemeleri verip uygun bir sorgu pattern'i oluşturmasını isteyebiliriz.
    # Bu örnekte, malzemelerin çoğunu içeren tarifleri bulmaya yönelik bir Cypher sorgusu manuel oluşturulmuştur.
    # LLM'in bu sorguyu üretmesi hedeflenmelidir.

    # Örnek Cypher sorgusu (LLM tarafından üretilmesi hedeflenir)
    # Bu sorgu, verilen malzemelerden en az X tanesini içeren tarifleri bulur.
    # Daha gelişmiş bir LLM prompt'u ile bu sorgu dinamik olarak üretilebilir.
    cypher_query = f"""
    MATCH (r:Recipe)-[:CONTAINS]->(i:Ingredient)
    WHERE i.name IN {malzemeler_listesi}
    WITH r, collect(i.name) AS recipe_ingredients, {malzemeler_listesi} AS available_ingredients
    WITH r, recipe_ingredients, available_ingredients,
         [x IN recipe_ingredients WHERE x IN available_ingredients] AS common_ingredients
    WHERE size(common_ingredients) > 0 // En az bir ortak malzeme
    RETURN r.name AS recipe_name, size(common_ingredients) AS common_ingredient_count, recipe_ingredients
    ORDER BY common_ingredient_count DESC
    LIMIT 5
    """
    try:
        results = graph.query(cypher_query)
        if not results:
            return "Belirttiğiniz malzemelerle eşleşen tarif bulunamadı."

        öneriler = "Bulunan tarifler:\n"
        for record in results:
            öneriler += f"- {record['recipe_name']} ({record['common_ingredient_count']} ortak malzeme: {record['recipe_ingredients']})\n"
        return öneriler
    except Exception as e:
        return f"Sorgu çalıştırılırken hata oluştu: {e}"


# Zinciri oluşturma
malzeme_tarif_zinciri = (
    {"malzemeler": RunnablePassthrough(), "schema": lambda: graph.get_schema} # şemayı dinamik olarak al
    | RunnablePassthrough.assign(öneri=malzemeler_ile_tarif_bul_ve_oner) # Kendi fonksiyonumuzu çağır
)

# Zinciri çalıştırma
kullanici_malzemeleri = "Süt, Şeker, Pirinç"
yanit = malzeme_tarif_zinciri.invoke(kullanici_malzemeleri)
print(f"Elimdeki malzemeler: {kullanici_malzemeleri}\nÖneriler:\n{yanit['öneri']}")

kullanici_malzemeleri_2 = "Un, Yumurta, Tereyağı"
yanit_2 = malzeme_tarif_zinciri.invoke(kullanici_malzemeleri_2)
print(f"Elimdeki malzemeler: {kullanici_malzemeleri_2}\nÖneriler:\n{yanit_2['öneri']}")
